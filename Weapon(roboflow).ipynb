# %% [markdown]
# <a href="https://colab.research.google.com/github/JARIN-TIAS/weapon-detection-with-roboflow/blob/main/Weapon(roboflow).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# Cloning into 'Licence-Plate-Detection-using-YOLO-V8'...
# remote: Enumerating objects: 117, done.
# remote: Total 117 (delta 0), reused 0 (delta 0), pack-reused 117
# Receiving objects: 100% (117/117), 183.86 KiB | 1012.00 KiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
# Out:
# [Errno 2] No such file or directory: '/content//content/Weapon-2'
# /content

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="6xXpmbz0tfJ5ZJfzKTJh")
project = rf.workspace("workshop-yg2yt").project("weapon-qo3kr")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to Weapon-2 in yolov8:: 100%|██████████| 1648/1648 [00:00<00:00, 2482.63it/s]

# %%
import subprocess
import sys

requirements = [
    "ultralytics==8.0.3",
    "hydra-core>=1.2.0",
    "matplotlib>=3.2.2",
    "numpy>=1.18.5",
    "opencv-python>=4.1.1",
    "Pillow>=7.1.2",
    "PyYAML>=5.3.1",
    "requests>=2.23.0",
    "scipy>=1.4.1",
    "torch>=1.7.0",
    "torchvision>=0.8.1",
    "tqdm>=4.64.0",
    "tensorboard>=2.4.1",
    "pandas>=1.1.4",
    "seaborn>=0.11.0",
    "ipython",
    "psutil",
    "thop>=0.1.1",
    "GitPython>=3.1.24"
]

# Install each package
for package in requirements:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', package])

# %%
# !ls /content/Weapon-2/data.yaml
# Out:
# /content/Weapon-2/data.yaml

# %%
# !cat /content/Weapon-2/data.yaml
# Out:
# names:
# - Celurit
# - Linggis
# - handgun
# nc: 3
# roboflow:
#   license: CC BY 4.0
#   project: weapon-qo3kr
#   url: https://universe.roboflow.com/workshop-yg2yt/weapon-qo3kr/dataset/2
#   version: 2
#   workspace: workshop-yg2yt
# test: ../test/images
# train:/content/Weapon-2/train/images
# val: /content/Weapon-2/val/images

# %%
# %%writefile /content/Weapon-2/data.yaml
# names:
#   - Celurit
#   - Linggis
#   - handgun
# nc: 3
# roboflow:
#   license: CC BY 4.0
#   project: weapon-qo3kr
#   url: https://universe.roboflow.com/workshop-yg2yt/weapon-qo3kr/dataset/2
#   version: 2
#   workspace: workshop-yg2yt
# test: ../test/images
# train: /content/Weapon-2/train/images
# val: /content/Weapon-2/val/images
# Out:
# Overwriting /content/Weapon-2/data.yaml

# %%
# %cd /content/Weapon-2
# !python train.py --model yolov8n.pt --data data.yaml --epochs 50
# Out:
# /content/Weapon-2
# ...
# 100% 6.23M/6.23M [00:00<00:00, 128MB/s]
#
# ...

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO('/content/Weapon-2/runs/detect/train/weights/best.pt')
# Out:
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.

# %%
results = model.predict(source='/content/Weapon-2/Screenshot (153).png', save=True)
# Out:
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 168 layers, 3006233 parameters, 0 gradients
# image 1/1 /content/Weapon-2/Screenshot (153).png: 480x640 1 handgun, 61.0ms
# Speed: 0.6ms pre-process, 61.0ms inference, 557.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict7

# %%
#!python /content/Weapon-2/runs/detect/predict.py model='/content/Weapon-2/runs/detect/train/weights/best.pt' source='/content/Weapon-2/weapon1.jpg'
# Out:
# python3: can't open file '/content/Weapon-2/runs/detect/predict.py': [Errno 2] No such file or directory

# %%
# !python /content/Licence-Plate-Detection-using-YOLO-V8/ultralytics/yolo/v8/detect/predict.py model='/content/Licence-Plate-Detection-using-YOLO-V8/runs/detect/train11/weights/best.pt' source='/content/Licence-Plate-Detection-using-YOLO-V8/nm.jpeg'
# Out:
# 2023-09-02 10:16:10.876094: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-02 10:16:12.318694: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.3 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# image 1/1 /content/Licence-Plate-Detection-using-YOLO-V8/nm.jpeg: 512x640 1 LicensePlate, 60.3ms
# Speed: 0.5ms pre-process, 60.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train13
